# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.0/670.0 kB 14.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 53.3 MB/s eta 0:00:00
# ...

# %%
import pymongo
import pandas as pd

# Replace the connection string with your MongoDB deployment URI
connection_string = 'mongodb://talentedge:talentedge@10.0.110.212:27017/talentedge?retryWrites=true&w=majority'

# Establish connection to MongoDB
client = pymongo.MongoClient(connection_string)

# Access a specific database, replace 'your_database' with your actual database name
db = client['talentedge']

# Access a specific collection in the database, replace 'your_collection' with your actual collection name
collection = db['requisitionYearlyDump']


# data = pd.DataFrame(list(collection.find({"location.state" : "NY"})))
# data


# Get the data by job title

query = { "title": "Data Scientist" }
data = pd.DataFrame(list(collection.find(query)))
data


# Get first x data items from a query

# # Retrieve 10 records from the collection
# cursor = collection.find(query) #.limit(10)
# # Iterate over the cursor to print the documents
# for document in cursor:
#     print(document)

# # Close the connection when done
# client.close()
# Out:
#                            _id  \
# 0     660fa38ce9e7718894ea99bf
# 1     660fa38ce9e7718894ea9a52
# 2     660fa38ce9e7718894eaa968
# 3     660fa38ce9e7718894eaaf39
# 4     660fa38ce9e7718894eabdeb
# ...                        ...
# 5041  661d77e6d7c0a99755f122b6
# 5042  661d7838d7c0a99755f178a0
# 5043  661d793bd7c0a99755f2510d
# 5044  661d793bd7c0a99755f27462
# 5045  661d79ead7c0a99755f30bd6
#
#                                          requiredSkills  \
# 0     [Artificial Intelligence, Computer Skills, Sof...
# 1     [statistical modeling, web application develop...
# 2                                [statistical modeling]
# 3                                                    []
# 4                                   [Data As A Service]
# ...                                                 ...
# 5041             [Analytics, Research, api, fast-paced]
# 5042  [Ability To Learn, Analytical, Analytics, Anal...
# 5043  [Analytics, Attention To Detail, Compliance, C...
# ...

# %%
#len(cursor)
